# %%
# !pip install graphviz
# Out:
# Requirement already satisfied: graphviz in /Users/dchaplinsky/Projects/wordnet_questionmark/venv/lib/python3.9/site-packages (0.17)
# ^C

# %%
from dataclasses import dataclass
from collections import defaultdict
from typing import List, Set, Optional, DefaultDict
import os.path
import logging
import graphviz

logger = logging.getLogger("uk_wordnet")


@dataclass
class LexicalUnit:
    name: str

    def __str__(self):
        return self.name

    def __hash__(self):
        return hash(self.name)


@dataclass
class RelationType:
    name: str

    def __str__(self):
        return self.name

    def __hash__(self):
        return hash((self.name,))

    def __eq__(self, othr):
        if isinstance(othr, type(self)):
            return self.name == othr.name

        if isinstance(othr, str):
            return self.name == othr

        return False


@dataclass
class Synset:
    lexical_unit: LexicalUnit
    definition: str
    variant: int
    relations: DefaultDict[RelationType, List]

    def __str__(self):
        return f"{self.lexical_unit.name}.{self.variant}"

    def __hash__(self):
        return hash((self.lexical_unit.name, self.variant))


class Wordnet:
    synset_lookup = defaultdict(list)
    relation_lookup = {}

    def deref_synset(self, synset):
        synsets_found = len(self.synset_lookup[synset])
        if synsets_found > 1:
            logger.warning(
                f"'{synset}' lexical unit has more than 1 synset, it has {synsets_found}!"
            )
            return None
        elif synsets_found == 0:
            logger.warning(f"'{synset}' lexical unit has no synsets at all!")
            return None

        return self.synset_lookup[synset][0]

    def __init__(self, concepts_file, relation_files):

        with open(concepts_file) as fp:
            for l in fp:
                lemma, gloss = l.strip().split(": ")
                lu = LexicalUnit(name=lemma)

                variant = len(synset_lookup[lemma])
                synset = Synset(
                    lexical_unit=lu,
                    definition=gloss,
                    variant=variant,
                    relations=defaultdict(list),
                )
                self.synset_lookup[lemma].append(synset)

        for rel_file in relation_files:
            rel_name, _ = os.path.splitext(os.path.basename(rel_file))
            rel = RelationType(name=rel_name)
            self.relation_lookup[rel_name] = rel

            with open(rel_file, "r") as fp:
                for l in fp:
                    l = l.strip()
                    if not l:
                        continue

                    try:
                        subj, obj = l.split(" -> ")
                    except ValueError:
                        logger.warning(
                            f"Cannot parse relation '{l}' of type '{rel_name}'"
                        )
                        continue

                    subj_deref = self.deref_synset(subj)
                    obj_deref = self.deref_synset(obj)

                    if subj_deref is None or obj_deref is None:
                        logger.warning(
                            f"Skipping relation of type '{rel_name}' between '{subj}' and '{obj}'"
                        )
                        continue

                    subj_deref.relations[rel].append("obj_deref")

    def export_to_graphviz(self, only_relations=None, ignore_orphans=False):
        if only_relations is None:
            only_relations = list(self.relation_lookup.values())
            

        g = graphviz.Graph("G", filename="process.gv")

        for synset_group in self.synset_lookup.values():
            for synset in synset_group:
                if any(synset.relations.values()) or not ignore_orphans:
                    g.node(str(synset))

                for rel in synset.relations:
                    if rel not in only_relations:
                        continue

                    for obj in synset.relations[rel]:
                        g.node(str(obj))
                        g.edge(str(synset), str(obj), label=str(rel))

        return g


import glob

wn = Wordnet(
    concepts_file="../resources/wn-ua-2009/basic-concepts.txt",
    relation_files=[
        f
        for f in glob.glob("../resources/wn-ua-2009/*.txt")
        
        if os.path.basename(f) not in ["readme.txt", "basic-concepts.txt"]
    ],
)
# Out:
# 'вік, тисячоліття' lexical unit has no synsets at all!
# 'століття' lexical unit has no synsets at all!
# Skipping relation of type 'part-meronym' between 'вік, тисячоліття' and 'століття'
# 'століття' lexical unit has no synsets at all!
# 'десятиліття' lexical unit has no synsets at all!
# Skipping relation of type 'part-meronym' between 'століття' and 'десятиліття'
# 'десятиліття' lexical unit has no synsets at all!
# 'рік' lexical unit has more than 1 synset, it has 2!
# Skipping relation of type 'part-meronym' between 'десятиліття' and 'рік'
# 'рік' lexical unit has more than 1 synset, it has 2!
# 'пора року' lexical unit has no synsets at all!
# Skipping relation of type 'part-meronym' between 'рік' and 'пора року'
# 'пора року' lexical unit has no synsets at all!
# 'місяць' lexical unit has more than 1 synset, it has 3!
# Skipping relation of type 'part-meronym' between 'пора року' and 'місяць'
# 'ранок' lexical unit has no synsets at all!
# 'світанок' lexical unit has no synsets at all!
# Skipping relation of type 'part-meronym' between 'ранок' and 'світанок'
# 'обід' lexical unit has no synsets at all!
# Skipping relation of type 'part-meronym' between 'день' and 'обід'
# 'біологічна група' lexical unit has no synsets at all!
# Skipping relation of type 'part-meronym' between 'об'єднання, група' and 'біологічна група'
# 'біологічна група' lexical unit has no synsets at all!
# 'домен' lexical unit has no synsets at all!
# Skipping relation of type 'part-meronym' between 'біологічна група' and 'домен'
# 'домен' lexical unit has no synsets at all!
# 'царство' lexical unit has no synsets at all!
# Skipping relation of type 'part-meronym' between 'домен' and 'царство'
# 'царство' lexical unit has no synsets at all!
# 'тип' lexical unit has no synsets at all!
# Skipping relation of type 'part-meronym' between 'царство' and 'тип'
# 'тип' lexical unit has no synsets at all!
# 'підтип' lexical unit has no synsets at all!
# Skipping relation of type 'part-meronym' between 'тип' and 'підтип'
# 'підтип' lexical unit has no synsets at all!
# 'клас' lexical unit has more than 1 synset, it has 3!
# Skipping relation of type 'part-meronym' between 'підтип' and 'клас'
# 'клас' lexical unit has more than 1 synset, it has 3!
# 'підклас' lexical unit has no synsets at all!
# Skipping relation of type 'part-meronym' between 'клас' and 'підклас'
# 'підклас' lexical unit has no synsets at all!
# 'ряд' lexical unit has more than 1 synset, it has 2!
# Skipping relation of type 'part-meronym' between 'підклас' and 'ряд'
# 'ряд' lexical unit has more than 1 synset, it has 2!
# 'рід' lexical unit has no synsets at all!
# Skipping relation of type 'part-meronym' between 'ряд' and 'рід'
# 'рід' lexical unit has no synsets at all!
# 'вид' lexical unit has more than 1 synset, it has 2!
# Skipping relation of type 'part-meronym' between 'рід' and 'вид'
# 'тіло, тіло людини' lexical unit has no synsets at all!
# 'частина тіла' lexical unit has no synsets at all!
# Skipping relation of type 'part-meronym' between 'тіло, тіло людини' and 'частина тіла'
# 'тіло, тіло людини' lexical unit has no synsets at all!
# 'клітина' lexical unit has no synsets at all!
# Skipping relation of type 'part-meronym' between 'тіло, тіло людини' and 'клітина'
# 'тканина' lexical unit has no synsets at all!
# 'клітина' lexical unit has no synsets at all!
# Skipping relation of type 'part-meronym' between 'тканина' and 'клітина'
# 'тіло, тіло людини' lexical unit has no synsets at all!
# 'тканина' lexical unit has no synsets at all!
# Skipping relation of type 'substance-meronym' between 'тіло, тіло людини' and 'тканина'
# 'представник хордових' lexical unit has no synsets at all!
# Skipping relation of type 'member-meronym' between 'хордові' and 'представник хордових'
# 'представник хребетних' lexical unit has no synsets at all!
# Skipping relation of type 'member-meronym' between 'хребетні' and 'представник хребетних'
# 'плацентарні' lexical unit has no synsets at all!
# 'представник плацентарних' lexical unit has no synsets at all!
# Skipping relation of type 'member-meronym' between 'плацентарні' and 'представник плацентарних'
# 'люди' lexical unit has no synsets at all!
# Skipping relation of type 'member-meronym' between 'люди' and 'людина'
# 'щось, невизначений носій спливу' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'вияв існування' and 'щось, невизначений носій спливу'
# 'величина' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'абстрактне поняття' and 'величина'
# 'матерія' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'об'єкт, об'єкт реальності' and 'матерія'
# 'об'єктивний процес' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'об'єкт, об'єкт реальності' and 'об'єктивний процес'
# 'працівник' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'людина, особа' and 'працівник'
# 'працівник' lexical unit has no synsets at all!
# 'науковець' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'працівник' and 'науковець'
# 'працівник' lexical unit has no synsets at all!
# 'працівник галузі мистецтва або культури' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'працівник' and 'працівник галузі мистецтва або культури'
# 'працівник' lexical unit has no synsets at all!
# 'представник духівництва' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'працівник' and 'представник духівництва'
# 'працівник' lexical unit has no synsets at all!
# 'юрист' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'працівник' and 'юрист'
# 'працівник' lexical unit has no synsets at all!
# 'інженер' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'працівник' and 'інженер'
# 'працівник' lexical unit has no synsets at all!
# 'медичний працівник' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'працівник' and 'медичний працівник'
# 'працівник' lexical unit has no synsets at all!
# 'економіст' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'працівник' and 'економіст'
# 'працівник' lexical unit has no synsets at all!
# 'робітник' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'працівник' and 'робітник'
# 'працівник' lexical unit has no synsets at all!
# 'військовий' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'працівник' and 'військовий'
# 'працівник' lexical unit has no synsets at all!
# 'службовець' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'працівник' and 'службовець'
# 'працівник' lexical unit has no synsets at all!
# 'працівник сфери обслуговування' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'працівник' and 'працівник сфери обслуговування'
# 'ціле' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'предмет' and 'ціле'
# 'ціле' lexical unit has no synsets at all!
# 'форма життя, істота' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'ціле' and 'форма життя, істота'
# 'форма життя, істота' lexical unit has no synsets at all!
# 'організм' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'форма життя, істота' and 'організм'
# 'організм' lexical unit has no synsets at all!
# 'представник ядерних' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'організм' and 'представник ядерних'
# 'представник ядерних' lexical unit has no synsets at all!
# 'тварина' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'представник ядерних' and 'тварина'
# 'тварина' lexical unit has no synsets at all!
# 'представник хордових' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'тварина' and 'представник хордових'
# 'представник хордових' lexical unit has no synsets at all!
# 'представник хребетних' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'представник хордових' and 'представник хребетних'
# 'представник хребетних' lexical unit has no synsets at all!
# 'ссавець' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'представник хребетних' and 'ссавець'
# 'ссавець' lexical unit has no synsets at all!
# 'представник плацентарних' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'ссавець' and 'представник плацентарних'
# 'представник плацентарних' lexical unit has no synsets at all!
# 'примат' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'представник плацентарних' and 'примат'
# 'примат' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'примат' and 'людина'
# 'людина розумна' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'людина' and 'людина розумна'
# 'стан' lexical unit has more than 1 synset, it has 2!
# Skipping relation of type 'hyponym' between 'характеристика' and 'стан'
# 'стан' lexical unit has more than 1 synset, it has 2!
# 'емоційні переживання' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'стан' and 'емоційні переживання'
# 'емоційні переживання' lexical unit has no synsets at all!
# 'емоційний стан' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоційні переживання' and 'емоційний стан'
# 'емоційні переживання' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоційні переживання' and 'почуття'
# 'емоційні переживання' lexical unit has no synsets at all!
# 'емоції' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоційні переживання' and 'емоції'
# 'емоційний стан' lexical unit has no synsets at all!
# 'емоційний тон' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоційний стан' and 'емоційний тон'
# 'емоційний стан' lexical unit has no synsets at all!
# 'настрій' lexical unit has more than 1 synset, it has 3!
# Skipping relation of type 'hyponym' between 'емоційний стан' and 'настрій'
# 'емоційний стан' lexical unit has no synsets at all!
# 'пристрасть' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоційний стан' and 'пристрасть'
# 'емоційний стан' lexical unit has no synsets at all!
# 'тривога' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоційний стан' and 'тривога'
# 'емоційний стан' lexical unit has no synsets at all!
# 'афект' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоційний стан' and 'афект'
# 'емоційний стан' lexical unit has no synsets at all!
# 'натхнення' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоційний стан' and 'натхнення'
# 'емоційний стан' lexical unit has no synsets at all!
# 'екстаз' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоційний стан' and 'екстаз'
# 'емоційний стан' lexical unit has no synsets at all!
# 'апатія' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоційний стан' and 'апатія'
# 'емоційний стан' lexical unit has no synsets at all!
# 'фрустрація' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоційний стан' and 'фрустрація'
# 'емоційний стан' lexical unit has no synsets at all!
# 'емпатія' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоційний стан' and 'емпатія'
# 'емоційний стан' lexical unit has no synsets at all!
# 'емоційне вигорання' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоційний стан' and 'емоційне вигорання'
# 'емоційний стан' lexical unit has no synsets at all!
# 'стрес' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоційний стан' and 'стрес'
# 'дружба' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'почуття' and 'дружба'
# 'сумнів, вагання' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'почуття' and 'сумнів, вагання'
# 'емоції' lexical unit has no synsets at all!
# 'інтерес' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоції' and 'інтерес'
# 'емоції' lexical unit has no synsets at all!
# 'радість' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоції' and 'радість'
# 'емоції' lexical unit has no synsets at all!
# 'здивування' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоції' and 'здивування'
# 'емоції' lexical unit has no synsets at all!
# 'гнів' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоції' and 'гнів'
# 'емоції' lexical unit has no synsets at all!
# 'відраза' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоції' and 'відраза'
# 'емоції' lexical unit has no synsets at all!
# 'презирство' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоції' and 'презирство'
# 'емоції' lexical unit has no synsets at all!
# 'сором' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоції' and 'сором'
# 'емоції' lexical unit has no synsets at all!
# 'сум' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоції' and 'сум'
# 'емоції' lexical unit has no synsets at all!
# 'провина' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоції' and 'провина'
# 'емоції' lexical unit has no synsets at all!
# 'страх' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'емоції' and 'страх'
# 'величина' lexical unit has no synsets at all!
# 'фундаментальна величина' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'величина' and 'фундаментальна величина'
# 'фундаментальна величина' lexical unit has no synsets at all!
# 'температура' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'фундаментальна величина' and 'температура'
# 'фундаментальна величина' lexical unit has no synsets at all!
# 'довжина' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'фундаментальна величина' and 'довжина'
# 'фундаментальна величина' lexical unit has no synsets at all!
# 'час' lexical unit has more than 1 synset, it has 3!
# Skipping relation of type 'hyponym' between 'фундаментальна величина' and 'час'
# 'фундаментальна величина' lexical unit has no synsets at all!
# 'маса' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'фундаментальна величина' and 'маса'
# 'час' lexical unit has more than 1 synset, it has 3!
# 'проміжок часу' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'час' and 'проміжок часу'
# 'час' lexical unit has more than 1 synset, it has 3!
# 'пора дня' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'час' and 'пора дня'
# 'час' lexical unit has more than 1 synset, it has 3!
# 'період життя' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'час' and 'період життя'
# 'проміжок часу' lexical unit has no synsets at all!
# 'вік, тисячоліття' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'проміжок часу' and 'вік, тисячоліття'
# 'проміжок часу' lexical unit has no synsets at all!
# 'епоха, вік' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'проміжок часу' and 'епоха, вік'
# 'проміжок часу' lexical unit has no synsets at all!
# 'пора, година' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'проміжок часу' and 'пора, година'
# 'проміжок часу' lexical unit has no synsets at all!
# 'хвиля, мить' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'проміжок часу' and 'хвиля, мить'
# 'проміжок часу' lexical unit has no synsets at all!
# 'відпочинковий час' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'проміжок часу' and 'відпочинковий час'
# 'пора дня' lexical unit has no synsets at all!
# 'світанок' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'пора дня' and 'світанок'
# 'пора дня' lexical unit has no synsets at all!
# 'ранок' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'пора дня' and 'ранок'
# 'пора дня' lexical unit has no synsets at all!
# 'обід' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'пора дня' and 'обід'
# 'пора дня' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'пора дня' and 'вечір'
# 'пора дня' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'пора дня' and 'день'
# 'пора дня' lexical unit has no synsets at all!
# 'ніч' lexical unit has more than 1 synset, it has 2!
# Skipping relation of type 'hyponym' between 'пора дня' and 'ніч'
# 'період життя' lexical unit has no synsets at all!
# 'молодість, юність' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'період життя' and 'молодість, юність'
# 'період життя' lexical unit has no synsets at all!
# 'старість' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'період життя' and 'старість'
# 'період життя' lexical unit has no synsets at all!
# 'дитинство' lexical unit has more than 1 synset, it has 2!
# Skipping relation of type 'hyponym' between 'період життя' and 'дитинство'
# 'ціле' lexical unit has no synsets at all!
# 'природний об'єкт' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'ціле' and 'природний об'єкт'
# 'природний об'єкт' lexical unit has no synsets at all!
# 'тіло' lexical unit has more than 1 synset, it has 2!
# Skipping relation of type 'hyponym' between 'природний об'єкт' and 'тіло'
# 'тіло' lexical unit has more than 1 synset, it has 2!
# 'живе тіло' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'тіло' and 'живе тіло'
# 'живе тіло' lexical unit has no synsets at all!
# 'тіло, тіло людини' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'живе тіло' and 'тіло, тіло людини'
# 'тип' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'тип' and 'хордові'
# 'підтип' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'підтип' and 'хребетні'
# 'підклас' lexical unit has no synsets at all!
# 'плацентарні' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'підклас' and 'плацентарні'
# 'рід' lexical unit has no synsets at all!
# 'люди' lexical unit has no synsets at all!
# Skipping relation of type 'hyponym' between 'рід' and 'люди'

# %%
wn.export_to_graphviz(only_relations=["hyponym"], ignore_orphans=True)

# %%
wn.export_to_graphviz(ignore_orphans=True)

# %%
l
# Out:
# defaultdict(list, {})
